# %% [markdown]
# # Replication and Extension
#
# This Notebook shows the code for the basic dynamism replicating Gopinath et al. and extending it with the newest time period.

# %%
from CompareCountries import CompareCountries
from MisallocationAnalysis import MisallocationAnalysis
import matplotlib.pyplot as plt

plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["cmr10", "Computer Modern Roman"],
    "mathtext.fontset": "cm",
    "axes.unicode_minus": False,
    "figure.dpi": 300,
    "savefig.dpi": 300,
})

# %%
spain2 = MisallocationAnalysis('Spain', start = 2014, end= 2024, sector='C')

# %% [markdown]
# ## Replication 2000-2012
# ### Marginal Revenue Products

# %%
spain = MisallocationAnalysis('Spain', start = 2000, end= 2012, sector='C')
mrpkfig = spain.plot_dispersion('MRPK')
mrplfig = spain.plot_dispersion('MRPL')
tfprfig = spain.plot_dispersion('TFPR')
capmoment = spain.plot_capital_tfp_moments()
mrpktfpr = spain.plot_dispersion_productivity()

# %% [markdown]
# ### Productivity

# %%
prod_permanent = spain.plot_productivity(sample='permanent')
prod_full = spain.plot_productivity(sample='full')

# %% [markdown]
# ## Extension 2012-2014
# ### Dispersion of Marginal Products

# %%
spain2 = MisallocationAnalysis('Spain', start = 2012, end= 2024, sector='C')
mrpkfig = spain2.plot_dispersion('MRPK')
mrplfig = spain2.plot_dispersion('MRPL')
tfprfig = spain2.plot_dispersion('TFPR')
capmoment = spain2.plot_capital_tfp_moments()
mrpktfpr = spain2.plot_dispersion_productivity()

# %% [markdown]
# ### Productivity

# %%
prod_permanent = spain2.plot_productivity(sample='permanent')
prod_full = spain2.plot_productivity(sample='full')

# %% [markdown]
# ## Comparison

# %%
#create another timespan for firm-level moments
spain_m = MisallocationAnalysis('Spain', 2000,2007, sector='C')
spain_m2 = MisallocationAnalysis('Spain', 2014,2020, sector='C')
compare_m = CompareCountries([spain_m, spain_m2])
#compare full time span
compare = CompareCountries([spain, spain2])

# %% [markdown]
# ### Descriptive Statistics

# %%
compare.descriptive_statistics()
# Out:
#      Variables Country     Period         Sector     count     mean  \
# 0       assets   Spain  2000-2012  Manufacturing  358528.0  4122.38
# 1      revenue   Spain  2000-2012  Manufacturing  358528.0  8187.19
# 2    materials   Spain  2000-2012  Manufacturing  358528.0  5092.76
# 3     wagebill   Spain  2000-2012  Manufacturing  358528.0  1150.87
# 4         debt   Spain  2000-2012  Manufacturing  276817.0  1888.03
# 5   nEmployees   Spain  2000-2012  Manufacturing  358528.0    33.68
# 6       assets   Spain  2012-2024  Manufacturing  583566.0  3563.53
# 7      revenue   Spain  2012-2024  Manufacturing  583566.0  6978.78
# 8    materials   Spain  2012-2024  Manufacturing  583566.0  4413.94
# 9     wagebill   Spain  2012-2024  Manufacturing  583566.0   965.83
# 10        debt   Spain  2012-2024  Manufacturing  440514.0  1473.06
# 11  nEmployees   Spain  2012-2024  Manufacturing  583566.0    23.94
#
#           std   min     25%     50%      75%         max
# 0    40568.95  0.01  170.00  522.97  1959.86   6802434.0
# 1   118082.46  0.09  328.13  922.11  3282.03  26009627.0
# 2    91293.16  0.00  112.69  396.00  1675.00  21616991.0
# 3     6884.26  0.00  105.00  262.99   719.00    634056.0
# 4    53317.41  0.00   21.60  120.99   487.00  12226850.0
# 5      162.76  1.00    4.00   10.00    26.00     16073.0
# 6    38974.80  0.00  172.36  487.00  1576.62   7789932.0
# 7   116318.83  0.06  303.06  809.72  2529.03  28927756.0
# 8    96516.01  0.00  105.81  342.65  1273.78  25283109.0
# 9     5764.99  0.00   92.91  231.41   604.22    549413.0
# 10   48335.52  0.00   21.84  107.38   406.12  10565790.0
# 11     109.18  1.00    3.00    7.00    18.00     14029.0

# %%
compare.overview_statistics()
# Out:
#   Country       Period         Sector  Avg. n. Firms  Avg. Revenue Covered  \
# 0   Spain  2000 - 2012  Manufacturing       27579.08                  0.49
# 1   Spain  2012 - 2024  Manufacturing       44889.69                  0.58
#
#    Top 20% Share of Capital
# 0                      0.87
# 1                      0.88

# %% [markdown]
# ### Firm Level Moments

# %%
compare_m.compare_all_moments()
# Out:
#                                       Spain 2000-2007  Spain 2014-2020
# Std.dev.(log Z_pow)                             2.050            2.220
# Std.dev.(log k)                                 1.770            1.800
# Std.dev.(log l)                                 1.550            1.630
# Top 20% Share of l                              0.780            0.790
# Top 20% Share of k                              0.820            0.850
# Coef log_Z on capital growth                    0.081            0.043
# Coef log_a on capital growth                    0.033            0.048
# Coef log_k on capital growth                   -1.071           -1.024
# Coef log_Z on capital growth t_0 - T            0.079            0.042
# Coef log_a on capital growth t_0 - T            0.038            0.045
# Coef log_k on capital growth t_0 - T           -1.045           -0.869
# Coef log_Z on debt growth                       0.004            0.024
# Coef log_a on debt growth                       0.003            0.023
# Coef log_k on debt growth                      -0.242           -0.198
# Fraction borrowing                              0.700            0.690
# Corr (log Z, log k)                             0.710            0.600
# Corr (log Z, log a)                             0.660            0.530
# Corr (log MRPK, log Z)                          0.070            0.310
# Corr (log MRPK, log k)                         -0.480           -0.390
# Corr (log MRPK, log a)                         -0.360           -0.300

# %%
import warnings
import importlib
warnings.filterwarnings('ignore')
import MisallocationAnalysis
importlib.reload(MisallocationAnalysis)
from MisallocationAnalysis import MisallocationAnalysis

# %%
fullspain = MisallocationAnalysis('Spain', start = 2000, end= 2024)
fullspain.compare_df_eurostats()
# Out:
#     Year  Turnover  Wages  Value Added  Firms  Employees
# 0   2000      0.64   0.76         0.88   0.20       0.52
# 1   2001      0.68   0.80         0.97   0.24       0.55
# 2   2002      0.70   0.83         0.97   0.27       0.57
# 3   2003      0.65   0.72         0.88   0.17       0.47
# 4   2004      0.67   0.74         0.92   0.18       0.49
# 5   2005      0.78   0.95         1.10   0.34       0.66
# 6   2006      0.80   0.95         1.12   0.35       0.67
# 7   2007      0.74   0.93         1.09   0.34       0.67
# 8   2008      0.77   0.94         1.12   0.35       0.67
# 9   2009      0.79   0.97         1.24   0.37       0.70
# 10  2010      0.80   0.97         1.18   0.36       0.70
# 11  2011      0.76   0.98         1.18   0.36       0.70
# 12  2012      0.83   1.00         1.28   0.36       0.71
# 13  2013      0.83   1.02         1.29   0.36       0.71
# 14  2014      0.84   1.06         1.29   0.37       0.74
# 15  2015      0.85   1.07         1.33   0.37       0.75
# 16  2016      0.86   1.09         1.35   0.38       0.74
# 17  2017      0.85   1.08         1.32   0.38       0.74
# 18  2018      0.81   1.03         1.25   0.37       0.72
# 19  2019      0.83   1.04         1.32   0.37       0.73
# 20  2020      0.82   1.04         1.29   0.37       0.71
# 21  2021      0.80   1.01         1.19   0.36       0.70
# 22  2022      0.82   1.03         1.27   0.36       0.72
# 23  2023      0.81   0.99         1.23   0.36       0.71
# 24  2024      0.67    NaN          NaN   0.30       0.58

# %%
fig  = fullspain.plot_mrpk_tfp_realrate()

# %%
portugal = MisallocationAnalysis('Portugal', start = 2000, end=2024)
portugal.compare_df_eurostats()
fig = portugal.plot_mrpk_tfp_realrate()

# %%
italy = MisallocationAnalysis('Italy')
print(italy.compare_df_eurostats())
fig = italy.plot_mrpk_tfp_realrate()
# Out:
#    Year  Turnover  Wages  Value Added  Firms  Employees
# 0  2015      0.81   1.09         1.47   0.24       0.64
# 1  2016      0.82   1.11         1.44   0.24       0.65
# 2  2017      0.80   1.08         1.38   0.25       0.65
# 3  2018      0.79   1.11         1.38   0.26       0.66
# 4  2019      0.80   1.11         1.42   0.27       0.67
# 5  2020      0.82   1.12         1.43   0.27       0.68
# 6  2021      0.85   1.16         1.42   0.28       0.70
# 7  2022      0.84   1.16         1.42   0.28       0.70
# 8  2023      0.83   1.15         1.41   0.29       0.69
# 9  2024      0.83    NaN          NaN   0.28       0.68

# %%
romania = MisallocationAnalysis('Romania')
print(romania.compare_df_eurostats())
fig = romania.plot_mrpk_tfp_realrate()
# Out:
#    Year  Turnover  Wages  Value Added  Firms  Employees
# 0  2015      0.79   0.98         1.45   0.56       0.80
# 1  2016      0.82   0.99         1.41   0.58       0.81
# 2  2017      0.82   0.98         1.34   0.60       0.83
# 3  2018      0.77   0.84         1.21   0.60       0.82
# 4  2019      0.75   0.82         1.22   0.61       0.82
# 5  2020      0.81   0.88         1.36   0.65       0.86
# 6  2021      0.78   0.88         1.25   0.49       9.62
# 7  2022      0.74   0.88         1.21   0.52       0.86
# 8  2023      0.78   0.86         1.32   0.52       0.84
# 9  2024      0.80    NaN          NaN   0.51       0.82

# %%
bulgaria = MisallocationAnalysis('Bulgaria')
print(bulgaria.compare_df_eurostats())
fig = bulgaria.plot_mrpk_tfp_realrate()
# Out:
#    Year  Turnover  Wages  Value Added  Firms  Employees
# 0  2015      0.85   1.06         1.78   0.52       0.97
# 1  2016      0.87   1.07         1.63   0.53       0.97
# 2  2017      0.87   1.08         1.67   0.54       0.98
# 3  2018      0.87   1.08         1.69   0.55       0.97
# 4  2019      0.88   1.09         1.72   0.57       0.98
# 5  2020      0.98   1.11         1.78   0.58       1.00
# 6  2021      1.01   1.10         1.96   0.59       1.00
# 7  2022      0.85   0.85         1.58   0.07       0.62
# 8  2023      0.72   0.72         1.30   0.04       0.50
# 9  2024      0.48    NaN          NaN   0.02       0.30

# %%
hungary = MisallocationAnalysis('Hungary')
print(hungary.compare_df_eurostats())
fig = hungary.plot_mrpk_tfp_realrate()
# Out:
#    Year  Turnover  Wages  Value Added  Firms  Employees
# 0  2015      0.83   0.82         1.54   0.05       0.58
# 1  2016      0.67   0.77         1.03   0.04       0.55
# 2  2017      0.70   0.76         1.04   0.04       0.56
# 3  2018      0.69   0.73         0.99   0.04       0.54
# 4  2019      0.68   0.71         0.99   0.04       0.53
# 5  2020      0.64   0.66         0.94   0.04       0.53
# 6  2021      0.66   0.66         0.91   0.03       0.54
# 7  2022      0.66   0.65         0.94   0.03       0.54
# 8  2023      0.67   0.66         0.98   0.04       0.54
# 9  2024      0.65    NaN          NaN   0.04       0.54

# %%
germany = MisallocationAnalysis('Germany')
print(germany.compare_df_eurostats())
fig = germany.plot_mrpk_tfp_realrate()
# Out:
#    Year  Turnover  Wages  Value Added  Firms  Employees
# 0  2015      0.38   0.41         0.59   0.02       0.26
# 1  2016      0.39   0.42         0.62   0.02       0.27
# 2  2017      0.35   0.39         0.60   0.02       0.26
# 3  2018      0.29   0.33         0.47   0.02       0.22
# 4  2019      0.32   0.35         0.50   0.02       0.25
# 5  2020      0.33   0.37         0.53   0.02       0.26
# 6  2021      0.31   0.35         0.47   0.02       0.24
# 7  2022      0.30   0.36         0.45   0.02       0.25
# 8  2023      0.30   0.33         0.46   0.02       0.24
# 9  2024      0.15    NaN          NaN   0.01       0.11

# %%
france = MisallocationAnalysis('France')
print(france.compare_df_eurostats())
fig = france.plot_mrpk_tfp_realrate()
# Out:
#    Year  Turnover  Wages  Value Added  Firms  Employees
# 0  2015      0.58   0.69         0.54   0.06       0.43
# 1  2016      0.56   0.73         0.56   0.05       0.45
# 2  2017      0.55   0.64         0.51   0.05       0.41
# 3  2018      0.53   0.62         0.49   0.05       0.39
# 4  2019      0.59   0.62         0.50   0.04       0.39
# 5  2020      0.47   0.55         0.43   0.04       0.35
# 6  2021      0.50   0.55         0.44   0.03       0.33
# 7  2022      0.28   0.33         0.26   0.01       0.17
# 8  2023      0.29   0.33         0.27   0.01       0.18
# 9  2024      0.36    NaN          NaN   0.01       0.20

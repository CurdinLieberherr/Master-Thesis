# %%
import warnings
import importlib
warnings.filterwarnings('ignore')
import MisallocationAnalysis
importlib.reload(MisallocationAnalysis)
from MisallocationAnalysis import MisallocationAnalysis


spain = MisallocationAnalysis('ES')
print(spain.compare_df_eurostats())
fig  = spain.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015     0.84653
# 1  2016    0.855248
# 2  2017    0.847808
# 3  2018    0.812065
# 4  2019    0.826773
# 5  2020    0.819654
# 6  2021    0.798556
# 7  2022    0.819756
# 8  2023    0.808568
# 9  2024    0.669834

# %%
portugal = MisallocationAnalysis('PT')
print(portugal.compare_df_eurostats())
fig = portugal.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015    0.775169
# 1  2016    0.741294
# 2  2017     0.74582
# 3  2018    0.736495
# 4  2019    0.742144
# 5  2020    0.763683
# 6  2021    0.744981
# 7  2022    0.709252
# 8  2023    0.728848

# %%
italy = MisallocationAnalysis('IT')
print(italy.compare_df_eurostats())
fig = italy.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015    0.809423
# 1  2016    0.817038
# 2  2017    0.798563
# 3  2018    0.790741
# 4  2019    0.802917
# 5  2020    0.821222
# 6  2021    0.845209
# 7  2022     0.83999
# 8  2023    0.828483

# %%
romania = MisallocationAnalysis('RO')
print(romania.compare_df_eurostats())
fig = romania.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015    0.792927
# 1  2016    0.818645
# 2  2017    0.818673
# 3  2018    0.767861
# 4  2019    0.754323
# 5  2020    0.807939
# 6  2021    0.775968
# 7  2022    0.741813
# 8  2023    0.782605

# %%
bulgaria = MisallocationAnalysis('BG')
print(bulgaria.compare_df_eurostats())
fig = bulgaria.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015    0.946298
# 1  2016    0.864277
# 2  2017    0.871585
# 3  2018    0.870405
# 4  2019    0.880589
# 5  2020     0.98004
# 6  2021    1.010516
# 7  2022    0.852023
# 8  2023    0.717965

# %%
hungary = MisallocationAnalysis('HU')
print(hungary.compare_df_eurostats())
fig = hungary.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015     0.83304
# 1  2016    0.668695
# 2  2017    0.697733
# 3  2018    0.694272
# 4  2019    0.675093
# 5  2020     0.64206
# 6  2021    0.662109
# 7  2022    0.664805
# 8  2023    0.671046

# %%
germany = MisallocationAnalysis('DE')
print(germany.compare_df_eurostats())
fig = germany.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015     0.38064
# 1  2016    0.388751
# 2  2017    0.354425
# 3  2018    0.331501
# 4  2019    0.288139
# 5  2020    0.269046
# 6  2021    0.280689
# 7  2022    0.262357
# 8  2023    0.260861

# %%
france = MisallocationAnalysis('FR')
print(france.compare_df_eurostats())
fig = france.plot_mrpk_tfp_realrate()
# Out:
#    Year Share Orbis
# 0  2015    0.583576
# 1  2016    0.557388
# 2  2017    0.545874
# 3  2018    0.532538
# 4  2019    0.586435
# 5  2020    0.467147
# 6  2021    0.498652
# 7  2022    0.284517
# 8  2023    0.289771

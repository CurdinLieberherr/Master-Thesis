# %%
import warnings
import importlib
warnings.filterwarnings('ignore')
import MisallocationAnalysis
importlib.reload(MisallocationAnalysis)
from MisallocationAnalysis import MisallocationAnalysis

# %%
spain = MisallocationAnalysis('Spain', start = 2000, end= 2024)
print(spain.compare_df_eurostats())
fig  = spain.plot_mrpk_tfp_realrate()
figtau  = spain.plot_capital_wedges()
prodplotn = spain.plot_productivity(figsize = (6,6))
moments = spain.plot_capital_tfp_moments()
# Out:
#     Year  Turnover  Wages  Value Added  Firms  Employees
# 0   2000      0.39   0.47         0.58   0.06       0.30
# 1   2001      0.42   0.50         0.66   0.08       0.32
# 2   2002      0.45   0.53         0.68   0.09       0.34
# 3   2003      0.43   0.47         0.63   0.05       0.29
# 4   2004      0.44   0.49         0.65   0.06       0.31
# 5   2005      0.48   0.59         0.74   0.12       0.38
# 6   2006      0.50   0.58         0.74   0.12       0.39
# 7   2007      0.48   0.59         0.75   0.13       0.40
# 8   2008      0.54   0.67         0.84   0.21       0.47
# 9   2009      0.56   0.69         0.94   0.22       0.50
# 10  2010      0.56   0.69         0.88   0.22       0.50
# 11  2011      0.54   0.69         0.87   0.22       0.50
# 12  2012      0.57   0.72         0.96   0.22       0.51
# 13  2013      0.59   0.73         0.97   0.22       0.52
# 14  2014      0.56   0.76         0.94   0.23       0.53
# ...

# %%
portugal = MisallocationAnalysis('Portugal', start = 2016, end=2024)
print(portugal.compare_df_eurostats())
fig = portugal.plot_mrpk_tfp_realrate()
figtau  = portugal.plot_capital_wedges()
moments = portugal.plot_capital_tfp_moments()
firm_moments = portugal.estimate_all_moments()
firm_moments
# Out:
#    Year  Turnover  Wages  Value Added  Firms  Employees
# 0  2016      0.68   0.81         1.16   0.23       0.58
# 1  2017      0.69   0.83         1.15   0.23       0.59
# 2  2018      0.67   0.82         1.12   0.24       0.59
# 3  2019      0.67   0.81         1.13   0.24       0.59
# 4  2020      0.69   0.82         1.14   0.25       0.61
# 5  2021      0.64   0.82         1.04   0.24       0.61
# 6  2022      0.52   0.80         0.90   0.24       0.59
# 7  2023      0.51   0.80         0.85   0.24       0.60
# 8  2024      0.50    NaN          NaN   0.23       0.58
# Std.dev.(log Z_pow)                            2.230
# Std.dev.(log k)                                1.690
# Std.dev.(log l)                                1.590
# Top 20% Share of l                             0.810
# Top 20% Share of k                             0.870
# Coefficient of log_Z on firm capital growth    0.023
# Coefficient of log_a on firm capital growth    0.026
# ...

# %%
italy = MisallocationAnalysis('Italy', start=2000, end=2024)
print(italy.compare_df_eurostats())
fig = italy.plot_mrpk_tfp_realrate()
figtau  = italy.plot_capital_wedges()
moments = italy.plot_capital_tfp_moments()
# Out:
#     Year  Turnover  Wages  Value Added  Firms  Employees
# 0   2000      0.58   0.90         1.07   0.07       0.46
# 1   2001      0.55   0.79         1.00   0.07       0.40
# 2   2002      0.66   0.87         1.15   0.10       0.47
# 3   2003      0.70   1.08         1.30   0.08       0.48
# 4   2004      0.48   0.66         0.90   0.05       0.34
# 5   2005      0.56   0.76         1.02   0.06       0.38
# 6   2006      0.66   0.87         1.18   0.10       0.46
# 7   2007      0.66   0.87         1.19   0.11       0.46
# 8   2008      0.66   0.85         1.25   0.15       0.47
# 9   2009      0.65   0.82         1.29   0.13       0.45
# 10  2010      0.64   0.83         1.14   0.11       0.46
# 11  2011      0.76   1.02         1.37   0.20       0.58
# 12  2012      0.75   1.02         1.44   0.21       0.59
# 13  2013      0.78   1.05         1.45   0.22       0.61
# 14  2014      0.79   1.08         1.45   0.23       0.63
# ...

# %%
bulgaria = MisallocationAnalysis('Bulgaria', start=2011, end=2021)
print(bulgaria.compare_df_eurostats())
fig = bulgaria.plot_mrpk_tfp_realrate()
figtau  = bulgaria.plot_capital_wedges()
moments = bulgaria.plot_capital_tfp_moments()
# Out:
#     Year  Turnover  Wages  Value Added  Firms  Employees
# 0   2011      0.78   0.99         1.74   0.46       0.82
# 1   2012      0.78   1.02         1.84   0.50       0.94
# 2   2013      0.79   1.03         1.89   0.50       0.92
# 3   2014      0.82   1.04         1.85   0.52       0.93
# 4   2015      0.85   1.06         1.78   0.52       0.97
# 5   2016      0.86   1.07         1.63   0.53       0.97
# 6   2017      0.87   1.08         1.67   0.54       0.98
# 7   2018      0.87   1.08         1.69   0.55       0.97
# 8   2019      0.88   1.09         1.71   0.57       0.98
# 9   2020      0.98   1.11         1.78   0.58       1.00
# 10  2021      1.01   1.10         1.96   0.59       1.00

# %%
hungary = MisallocationAnalysis('Hungary', start = 2007, end= 2024)
print(hungary.compare_df_eurostats())
fig = hungary.plot_mrpk_tfp_realrate()
figtau  = hungary.plot_capital_wedges()
moments = hungary.plot_capital_tfp_moments()
# Out:
#     Year  Turnover  Wages  Value Added  Firms  Employees
# 0   2007      0.39    NaN         0.65   0.04       0.38
# 1   2008      0.52   0.65         0.82   0.03       0.43
# 2   2009      0.69   0.80         1.19   0.05       0.52
# 3   2010      0.65   0.74         1.03   0.05       0.53
# 4   2011      0.61   0.68         0.94   0.05       0.53
# 5   2012      0.71   0.89         1.19   0.05       0.54
# 6   2013      0.73   0.92         1.20   0.05       0.56
# 7   2014      0.70   0.79         1.07   0.05       0.58
# 8   2015      0.83   0.82         1.54   0.05       0.58
# 9   2016      0.67   0.77         1.03   0.04       0.55
# 10  2017      0.70   0.76         1.04   0.04       0.56
# 11  2018      0.69   0.73         0.99   0.04       0.54
# 12  2019      0.68   0.71         0.99   0.04       0.53
# 13  2020      0.64   0.66         0.94   0.04       0.53
# 14  2021      0.66   0.66         0.91   0.03       0.54
# ...

# %%
germany = MisallocationAnalysis('Germany', start=2000, end=2024)
print(germany.compare_df_eurostats())
fig = germany.plot_mrpk_tfp_realrate()
figtau  = germany.plot_capital_wedges()
moments = germany.plot_capital_tfp_moments()
# Out:
#     Year  Turnover  Wages  Value Added  Firms  Employees
# 0   2000      0.12   0.13         0.18   0.01       0.10
# 1   2001      0.20   0.22         0.30   0.01       0.15
# 2   2002      0.25   0.30         0.41   0.00       0.17
# 3   2003      0.27   0.32         0.41   0.01       0.18
# 4   2004      0.26   0.30         0.39   0.01       0.17
# 5   2005      0.32   0.37         0.49   0.01       0.21
# 6   2006      0.34   0.41         0.52   0.02       0.25
# 7   2007      0.35   0.39         0.53   0.02       0.26
# 8   2008      0.35   0.39         0.54   0.02       0.26
# 9   2009      0.35   0.41         0.60   0.03       0.27
# 10  2010      0.36   0.39         0.56   0.02       0.26
# 11  2011      0.37   0.41         0.59   0.02       0.27
# 12  2012      0.38   0.42         0.62   0.03       0.28
# 13  2013      0.37   0.43         0.61   0.03       0.28
# 14  2014      0.36   0.40         0.57   0.02       0.26
# ...

# %%
france = MisallocationAnalysis('France', start = 2005, end= 2024)
print(france.compare_df_eurostats())
fig = france.plot_mrpk_tfp_realrate()
figwedges = france.plot_capital_wedges()
figtau  = france.plot_capital_wedges()
moments = france.plot_capital_tfp_moments()
# Out:
#     Year  Turnover  Wages  Value Added  Firms  Employees
# 0   2005      0.46   0.55         0.86   0.09       0.35
# 1   2006      0.47   0.55         0.89   0.09       0.35
# 2   2007      0.52   0.64         0.97   0.10       0.41
# 3   2008      0.48    NaN         0.92   0.10        NaN
# 4   2009      0.40   0.54         0.80   0.10        NaN
# 5   2010      0.51   0.59         0.87   0.09       0.37
# 6   2011      0.43   0.53         0.73   0.08       0.33
# 7   2012      0.37   0.44         0.34   0.06       0.27
# 8   2013      0.46   0.57         0.45   0.06       0.34
# 9   2014      0.56   0.67         0.51   0.07       0.41
# 10  2015      0.58   0.69         0.54   0.06       0.43
# 11  2016      0.56   0.73         0.56   0.05       0.45
# 12  2017      0.55   0.64         0.51   0.05       0.41
# 13  2018      0.53   0.62         0.49   0.05       0.39
# 14  2019      0.59   0.62         0.50   0.04       0.39
# ...

# %%
import importlib
import CompareCountries as cc
importlib.reload(cc)

countries = [spain, portugal, italy, france, hungary, bulgaria]

compare = cc.CompareCountries(countries, start=2000, end=2012)
fig = compare.plot_compare_mrpk()
compare.compare()
# Out:
#     Country         Time  Revenue Data Coverage %  \
# 0     Spain  2000 - 2012                    77.56
# 1  Portugal  2006 - 2012                    71.89
# 2     Italy  2000 - 2012                    72.28
# 3    France  2005 - 2012                    46.85
# 4   Hungary  2007 - 2012                    65.83
# 5  Bulgaria  2000 - 2012                    71.95
#
#    Change Real Interest Rate %  Change log MRPK %
# 0                         1.42              23.54
# 1                         6.84               3.31
# 2                        -0.79               9.88
# 3                        -1.17              29.72
# 4                         3.35              -5.89
# 5                          NaN              10.05

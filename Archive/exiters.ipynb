# %%
from MisallocationAnalysis import MisallocationAnalysis
import warnings
warnings.filterwarnings('ignore')

# %%
spain = MisallocationAnalysis('Spain', start = 2000, end= 2012)
fig = spain.plot_mrpk_exiters_vs_remainers()
sumdf, _ = spain.exiters_regression()
spain.plot_dispersion_all_vs_survivors()
sumdf
# Out:
#         coef  std_err  p_value
# log_Z -0.113    0.003      0.0
# log_a -0.338    0.004      0.0

# %%
spain1 = MisallocationAnalysis('Spain', start = 2015, end= 2023)
fig = spain1.plot_mrpk_exiters_vs_remainers()
sumdf, _ = spain1.exiters_regression()
spain1.plot_dispersion_all_vs_survivors()
sumdf
# Out:
#         coef  std_err  p_value
# log_Z -0.136    0.004      0.0
# log_a -0.315    0.004      0.0

# %%
import pycountry
import pycountry_convert as pc

european_countries = []

for country in pycountry.countries:
    try:
        continent_code = pc.country_alpha2_to_continent_code(country.alpha_2)
        if continent_code == 'EU':
            european_countries.append(country)
    except KeyError:
        # some countries/territories aren't mapped
        continue

# %%
import warnings
warnings.filterwarnings('ignore')
from MisallocationAnalysis import MisallocationAnalysis
import joblib

start=2015
end=2024
for country in european_countries:
    try:
        country_analysis = MisallocationAnalysis(country.name, start=start, end=end)
        country_analysis.estimate_all_moments()
        joblib.dump(country_analysis, f'analysis_database/{country.name}{start}-{end}.joblib')
        print('Success', country.name, start, 'to', end)
    except:
        print('Fail',start, 'to', end, country.name)
        pass
# Out:
# Fail 2015 to 2024 Åland Islands
# Fail 2015 to 2024 Albania
# Fail 2015 to 2024 Andorra
# Success Austria 2015 to 2024
# Success Belgium 2015 to 2024
# Success Bulgaria 2015 to 2024
# Fail 2015 to 2024 Bosnia and Herzegovina
# Fail 2015 to 2024 Belarus
# Success Switzerland 2015 to 2024
# Fail 2015 to 2024 Czechia
# Success Germany 2015 to 2024
# Fail 2015 to 2024 Denmark
# Success Spain 2015 to 2024
# Fail 2015 to 2024 Estonia
# Success Finland 2015 to 2024
# Success France 2015 to 2024
# Fail 2015 to 2024 Faroe Islands
# Fail 2015 to 2024 United Kingdom
# Fail 2015 to 2024 Guernsey
# Fail 2015 to 2024 Gibraltar
# Fail 2015 to 2024 Greece
# Success Croatia 2015 to 2024
# Success Hungary 2015 to 2024
# Fail 2015 to 2024 Isle of Man
# Fail 2015 to 2024 Ireland
# Fail 2015 to 2024 Iceland
# Success Italy 2015 to 2024
# Fail 2015 to 2024 Jersey
# Fail 2015 to 2024 Liechtenstein
# Fail 2015 to 2024 Lithuania
# Fail 2015 to 2024 Luxembourg
# Fail 2015 to 2024 Latvia
# Fail 2015 to 2024 Monaco
# Fail 2015 to 2024 Moldova, Republic of
# Success North Macedonia 2015 to 2024
# Fail 2015 to 2024 Malta
# Fail 2015 to 2024 Montenegro
# Success Netherlands 2015 to 2024
# Success Norway 2015 to 2024
# Success Poland 2015 to 2024
# Success Portugal 2015 to 2024
# Success Romania 2015 to 2024
# Fail 2015 to 2024 Russian Federation
# Fail 2015 to 2024 Svalbard and Jan Mayen
# Fail 2015 to 2024 San Marino
# Fail 2015 to 2024 Serbia
# Fail 2015 to 2024 Slovakia
# Success Slovenia 2015 to 2024
# Success Sweden 2015 to 2024
# Success Ukraine 2015 to 2024

# %%
import os
import joblib

all_countries = {}
for dir in os.listdir('corrected_analysis_database'):
    country_analysis = joblib.load('corrected_analysis_database/'+dir)
    all_countries[dir.replace('.joblib', '')] = country_analysis

# %%
import CompareCountries
import importlib
importlib.reload(CompareCountries)
from CompareCountries import CompareCountries

comparison = CompareCountries(all_countries.values())
compare_df = comparison.compare()

#only keep revenues above 30 percent and where both time periods are present
compare_df = compare_df[compare_df['Revenue Data Coverage %'] >= 20]
compare_df = compare_df[compare_df.groupby('Country')['Country'].transform('count') == 2]

# %%
compare_df = comparison.compare().sort_values(['Country', 'Time']).reset_index(drop=True)
asdf = compare_df[['Country', 'Revenue Data Coverage %', 'Time', 'Change Real Interest Rate %', 'Change log MRPK %', 'Coefficient of log_a on firm capital growth', 'P-Value Coefficient']]

countries = ['Spain', 'Belgium', 'Croatia', 'Bulgaria', 'Poland', 'Portugal', 'Germany', 'Sweden']
asdf = asdf[asdf['Country'].isin(countries)]

import pandas as pd

asdf['Country'] = pd.Categorical(
    asdf['Country'],
    categories=countries,
    ordered=True
)

asdf = asdf.sort_values('Country')
asdf
# Out:
#      Country  Revenue Data Coverage %         Time  \
# 11     Spain                    54.20  2000 - 2015
# 12     Spain                    50.78  2015 - 2024
# 0    Belgium                    59.38  2000 - 2015
# 1    Belgium                    52.56  2015 - 2024
# 4    Croatia                    63.00  2000 - 2015
# 5    Croatia                    65.56  2015 - 2024
# 2   Bulgaria                    53.71  2000 - 2015
# 3   Bulgaria                    68.22  2015 - 2024
# 8     Poland                    18.20  2000 - 2015
# 9     Poland                    26.89  2015 - 2024
# 10  Portugal                    59.11  2015 - 2024
# 6    Germany                     9.20  2000 - 2015
# 7    Germany                    10.56  2015 - 2024
#
#     Change Real Interest Rate %  Change log MRPK %  \
# 11                         0.30              20.42
# 12                        -2.08               1.22
# 0                         -2.65               9.87
# 1                         -1.62              -6.18
# 4                          2.41              20.85
# 5                         -4.52              -2.40
# 2                         -0.55              46.12
# 3                         -2.25             -51.09
# 8                         -1.98              -8.97
# 9                         -1.57              58.71
# 10                        -1.66               2.28
# 6                         -4.06             144.59
# 7                          0.02             -11.08
#
#     Coefficient of log_a on firm capital growth  P-Value Coefficient
# 11                                        0.029                0.000
# 12                                        0.034                0.000
# 0                                         0.037                0.000
# 1                                         0.060                0.000
# 4                                         0.025                0.122
# 5                                         0.125                0.001
# 2                                         0.059                0.473
# 3                                         0.059                0.000
# 8                                         0.008                0.619
# 9                                        -0.004                0.761
# 10                                        0.028                0.000
# 6                                         0.043                0.039
# 7                                         0.014                0.052

# %%
import warnings
warnings.filterwarnings('ignore')
from MisallocationAnalysis import MisallocationAnalysis
import joblib

start=2000
end=2015
for country in ['Spain', 'Belgium', 'Croatia', 'Bulgaria', 'Poland', 'Portugal', 'Germany', 'Sweden']:
    try:
        country_analysis = MisallocationAnalysis(country, start=start, end=end)
        country_analysis.estimate_all_moments()
        country_analysis.estimate_corrected_measures()
        country_analysis.inplace_correct_measures()
        joblib.dump(country_analysis, f'corrected_analysis_database/{country}{start}-{end}.joblib')
        print('Success', country, start, 'to', end)
    except:
        print('Fail',start, 'to', end, country)
        pass
# Out:
# 474302
# 352522
# Success Spain 2000 to 2015
# 30889
# 24962
# Success Belgium 2000 to 2015
# 69609
# 52606
# Success Croatia 2000 to 2015
# 77163
# 52242
# Success Bulgaria 2000 to 2015
# 35938
# 21429
# Success Poland 2000 to 2015
# 147378
# 110711
# Fail 2000 to 2015 Portugal
# 28046
# 18024
# Success Germany 2000 to 2015
# 66592
# 51590
# Fail 2000 to 2015 Sweden

# %%
from modules import capital_prices

capital_prices('Spain')
# Out:
# /Applications/anaconda3/envs/thesis/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    country  year  capitalprice
# 0    Spain  1992         0.658
# 1    Spain  1993         0.672
# 2    Spain  1994         0.689
# 3    Spain  1995         0.717
# 4    Spain  1996         0.737
# 5    Spain  1997         0.746
# 6    Spain  1998         0.753
# 7    Spain  1999         0.759
# 8    Spain  2000         0.769
# 9    Spain  2001         0.779
# 10   Spain  2002         0.793
# 11   Spain  2003         0.803
# 12   Spain  2004         0.814
# 13   Spain  2005         0.830
# 14   Spain  2006         0.855
# 15   Spain  2007         0.884
# 16   Spain  2008         0.906
# 17   Spain  2009         0.913
# 18   Spain  2010         0.917
# 19   Spain  2011         0.926
# 20   Spain  2012         0.931
# ...

# %%
# Out:
# /Applications/anaconda3/envs/thesis/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Applications/anaconda3/envs/thesis/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    country  year  nominalinterestrate  inflation  realinterestrate
# 0    Spain  1996             0.087400        NaN               NaN
# 1    Spain  1997             0.064000      0.019          0.045000
# 2    Spain  1998             0.048300      0.018          0.030300
# 3    Spain  1999             0.047300      0.022          0.025300
# 4    Spain  2000             0.055300      0.035          0.020300
# 5    Spain  2001             0.051200      0.028          0.023200
# ...
